# %% [markdown]
# # Generate Embeddings

# %% [markdown]
# ## Get Data

# %%
from raag_midi_gen.dataset import get_dataset

midi_files_dataset = get_dataset()

# %% [markdown]
# ## Build Embedding Layers

# %%
from torch.nn import Embedding

# %% [markdown]
# ### Note Embeddings

# %% [markdown]
# ### Octave Embeddings

# %% [markdown]
# ### Note Characteristics Embedding (Velocity & Length)
